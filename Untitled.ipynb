# %%
class Robot:
    def __init__(self, name ,coloer, weight):
        self.name = name
        self.coloer = coloer
        self.weight = weight
    def function(self):
        print(f"is name : {self.name}")

# %%
r1 = Robot("santoos", "a5dar", 32)

# %%
r1.function()
# Out:
# is name : santoos
